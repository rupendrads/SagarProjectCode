# %% [markdown]
# sma + ema
# if row['timestamp'].time() >= pd.Timestamp(strategy.start_time).time():
#                 if not in_trade and row['short_ma'] > row['long_ma'] and row['timestamp'] < end_time:
#                     in_trade = True
#                     entry_time = row['timestamp']
#                     entry_price = row['close'] + slippage
#                     trades_per_day += 1
#                     # logger.info(f"{row['timestamp']} entry at {entry_price}, short_ma @ {row['short_ma']} and long_ma @ {row['long_ma']}")

# %%
from datetime import datetime

# %%
time_now = datetime.now()

# %%
import pandas as pd
path = r'C:\Users\pegas\OneDrive\Desktop\pegasus-backtest-new\performance.csv'

# %%
df = pd.read_csv(path)
df
# Out:
#    start_time end_time  short_ma  long_ma  timeframe  stop_loss  \
# 0       11:55    14:45        27       44         26         20
# 1       09:35    14:45        21       38         17         20
# 2       10:20    15:00         5       14         27         20
# 3       11:35    14:45        19       38         11         20
# 4       09:35    14:30         5       24         28         20
# ..        ...      ...       ...      ...        ...        ...
# 79      10:30    15:00        29       38         28         20
# 80      10:15    15:00         9       20         25         20
# 81      12:00    14:45        15       32          6         20
# 82      10:20    14:30         9       20          1         20
# 83      11:20    14:30        13       26          1         20
#
#    moving_average  total_trades  winning_trades  losing_trades  ...  \
# 0             sma            85              39             46  ...
# ...

# %%
performance_list_files = list(df['tradebook_name'].apply(lambda x: str(x).split('/')[3]))

# %%
counter=0
for x in file_names:
    if x not in performance_list_files:
        print(x)
        counter+=1
# Out:
# moving_average_NIFTY_0930_1500_7_24_18_20_ematradebook.csv
# moving_average_NIFTY_0950_1430_27_40_29_20_smatradebook.csv
# moving_average_NIFTY_0950_1445_19_24_27_20_ematradebook.csv
# moving_average_NIFTY_0955_1445_17_24_9_20_ematradebook.csv
# moving_average_NIFTY_1000_1445_19_36_20_20_smatradebook.csv
# moving_average_NIFTY_1000_1500_5_12_7_20_ematradebook.csv
# moving_average_NIFTY_1020_1445_13_24_25_20_smatradebook.csv
# moving_average_NIFTY_1035_1445_27_32_22_20_ematradebook.csv
# moving_average_NIFTY_1045_1445_19_24_25_20_ematradebook.csv
# moving_average_NIFTY_1050_1430_15_24_18_20_smatradebook.csv
# moving_average_NIFTY_1100_1430_23_32_23_20_smatradebook.csv
# moving_average_NIFTY_1120_1500_27_38_24_20_smatradebook.csv
# moving_average_NIFTY_1125_1430_21_30_6_20_ematradebook.csv
# moving_average_NIFTY_1135_1445_11_22_21_20_smatradebook.csv
# moving_average_NIFTY_1140_1430_15_28_29_20_ematradebook.csv
# moving_average_NIFTY_1150_1500_23_42_19_20_ematradebook.csv

# %%
counter
# Out:
# 16

# %%
import os

# Directory path
folder_path = r'C:\Users\pegas\OneDrive\Desktop\pegasus-backtest-new\strategy\moving_average\check_files'

# Get all file names in the directory
all_files = os.listdir(folder_path)

# Filter out only the file names ending with ".csv"
csv_files = [file for file in all_files if file.endswith('.csv')]

# Print the list of CSV file names
file_names =[]
print("CSV files in the folder:")
for csv_file in csv_files:
#     file_name = csv_file.split('.csv')[0]
    file_names.append(csv_file)
# Out:
# CSV files in the folder:

# %%
len(file_names)
# Out:
# 100

# %%
file_names
# Out:
# ['moving_average_NIFTY_0930_1445_15_20_4_20_ematradebook.csv',
#  'moving_average_NIFTY_0930_1500_11_20_27_20_ematradebook.csv',
#  'moving_average_NIFTY_0930_1500_29_36_27_20_smatradebook.csv',
#  'moving_average_NIFTY_0930_1500_7_24_18_20_ematradebook.csv',
#  'moving_average_NIFTY_0935_1430_5_24_28_20_ematradebook.csv',
#  'moving_average_NIFTY_0935_1445_21_38_17_20_smatradebook.csv',
#  'moving_average_NIFTY_0935_1445_25_30_27_20_ematradebook.csv',
#  'moving_average_NIFTY_0935_1445_7_18_25_20_smatradebook.csv',
#  'moving_average_NIFTY_0935_1500_7_22_11_20_ematradebook.csv',
#  'moving_average_NIFTY_0940_1445_25_42_9_20_smatradebook.csv',
#  'moving_average_NIFTY_0940_1500_19_36_12_20_smatradebook.csv',
#  'moving_average_NIFTY_0945_1430_13_28_11_20_ematradebook.csv',
#  'moving_average_NIFTY_0950_1430_27_40_29_20_smatradebook.csv',
#  'moving_average_NIFTY_0950_1430_7_24_13_20_ematradebook.csv',
#  'moving_average_NIFTY_0950_1445_19_24_27_20_ematradebook.csv',
# ...

# %%
/strategy/moving_average/moving_average_NIFTY_1140_1445_11_30_13_20_ematradebook.csv'}
# Out:
#    start_time end_time  short_ma  long_ma  timeframe  stop_loss  \
# 0       11:05    14:45        17       34         26         20
# 1       11:20    14:45        27       44         18         20
# 2       10:10    14:30        21       26         21         20
# 3       11:25    14:30        15       34         28         20
# 4       11:25    14:45        21       34         30         20
# ..        ...      ...       ...      ...        ...        ...
# 89      09:30    14:30        29       34         30         20
# 90      11:35    14:30         5       14          4         20
# 91      11:20    14:30         7       16         14         20
# 92      10:40    14:30        29       42         15         20
# 93      10:55    14:45         7       26         10         20
#
#    moving_average  total_trades  winning_trades  losing_trades  ...  \
# 0             ema            97              39             58  ...
# ...

# %%
if time_now > strategy_time:
    short_ma => value
    long_ma => value
    ltp => instrument
    order punch
    65 ms => broker queue => nse server => execute => broker => broker => client => status => successful
    logger(trade reject/success)

# %%
# order_id => status => wait 3 second => status => reject =>

# %%
sqlite3 sql python + js

# %%
strategy => low latency = live // robust => backtesting
