# %%
import pandas as pd
import json

# %%
tradebook_df = pd.read_csv(r"C:\Users\pegas\OneDrive\Desktop\github\Sagar_Backend\time based strategy\strategy_live\sagar_tradebook.csv")

# %%
tradebook_df.sort_values("ExchangeTransactTimeAPI")
# Out:
#     AppOrderID                 TradingSymbol  ExchangeInstrumentID OrderSide  \
# 0   1210900020  BANKNIFTY 12JUN2024 CE 50100                 36846       Buy
# 1   1210900021  BANKNIFTY 12JUN2024 PE 50300                 36980       Buy
# 2   1210900022  BANKNIFTY 12JUN2024 CE 50100                 36846      Sell
# 3   1210900023  BANKNIFTY 12JUN2024 PE 50300                 36980      Sell
# 4   1210900071      NIFTY 13JUN2024 CE 22950                 43940       Buy
# 5   1210900072      NIFTY 13JUN2024 PE 23800                 44029       Buy
# 7   1210900074      NIFTY 13JUN2024 PE 23800                 44029      Sell
# 8   1210900077  BANKNIFTY 12JUN2024 CE 50100                 36846       Buy
# 9   1210900113  BANKNIFTY 12JUN2024 PE 50300                 36980       Buy
# 6   1210900073      NIFTY 13JUN2024 CE 22950                 43940      Sell
# 10  1210900144  BANKNIFTY 12JUN2024 CE 50100                 36846      Sell
# ...

# %%
tradebook_df[~tradebook_df['OrderUniqueIdentifier'].str.endswith(('_sl', '_cover'))]
# Out:
#     AppOrderID                 TradingSymbol  ExchangeInstrumentID OrderSide  \
# 0   1210900020  BANKNIFTY 12JUN2024 CE 50100                 36846       Buy
# 1   1210900021  BANKNIFTY 12JUN2024 PE 50300                 36980       Buy
# 4   1210900071      NIFTY 13JUN2024 CE 22950                 43940       Buy
# 5   1210900072      NIFTY 13JUN2024 PE 23800                 44029       Buy
# 8   1210900077  BANKNIFTY 12JUN2024 CE 50100                 36846       Buy
# 9   1210900113  BANKNIFTY 12JUN2024 PE 50300                 36980       Buy
# 12  1210900443  BANKNIFTY 12JUN2024 CE 50100                 36846      Sell
# 13  1210900456  BANKNIFTY 12JUN2024 PE 49600                 36801      Sell
# 16  1210900487  BANKNIFTY 12JUN2024 PE 50300                 36980       Buy
# 17  1210900496  BANKNIFTY 12JUN2024 PE 49600                 36801      Sell
# 18  1210900688  BANKNIFTY 12JUN2024 CE 50400                 37021      Sell
# ...

# %%
json.dumps({'exchangeSegment': 2, 'exchangeInstrumentID': 51670, 'clientID': 'IIFL11'})
# Out:
# '{"exchangeSegment": 2, "exchangeInstrumentID": 51670, "clientID": "IIFL11"}'

# %%
df = pd.read_csv('nfo.csv', low_memory=False)

# %%
entry_df.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 entry_df.columns
#
# NameError: name 'entry_df' is not defined

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 merged_df = pd.merge(entry_df, exit_df, left_index=True, right_index=True, how='outer')
#
# NameError: name 'entry_df' is not defined

# %%
df[df.ExchangeInstrumentID == 35004]["FreezeQty"].values[0]
# Out:
# 1801

# %%
d

# %%
position_columns = list(df.columns)

# %%
df[df['Quantity']!=0].iloc[0]
# Out:
# AccountID                                            IIFL11
# TradingSymbol                      NIFTY 16MAY2024 PE 22150
# ExchangeSegment                                       NSEFO
# ExchangeInstrumentId                                  51672
# ProductType                                            NRML
# Marketlot                                                25
# Multiplier                                                1
# BuyAveragePrice                                       198.1
# SellAveragePrice                                          0
# OpenBuyQuantity                                         175
# OpenSellQuantity                                          0
# Quantity                                                175
# BuyAmount                                           34667.5
# SellAmount                                                0
# NetAmount                                          -34667.5
# UnrealizedMTM                                           0.0
# ...

# %%
df = pd.read_csv('tradebook.csv')

# %%
set(df.OrderStatus)
# Out:
# {'Cancelled', 'Filled'}

# %%
df = pd.read_csv('trades.csv')

# %%
eg = {'LoginID': 'IIFL11', 'ClientID': 'IIFL11', 'AppOrderID': 1210046140}

# %%
data = [{'LoginID': 'IIFL11', 'ClientID': 'IIFL11', 'AppOrderID': 1210046140, 'OrderReferenceID': '', 'GeneratedBy': 'TWSAPI', 'ExchangeOrderID': 'X_137509099', 'OrderCategoryType': 'NORMAL', 'ExchangeSegment': 'NSEFO', 'ExchangeInstrumentID': 51674, 'OrderSide': 'Buy', 'OrderType': 'Market', 'ProductType': 'NRML', 'TimeInForce': 'DAY', 'OrderPrice': 0, 'OrderQuantity': 50, 'OrderStopPrice': 0, 'OrderStatus': 'New', 'OrderAverageTradedPrice': '', 'LeavesQuantity': 50, 'CumulativeQuantity': 0, 'OrderDisclosedQuantity': 0, 'OrderGeneratedDateTime': '2024-05-10T15:09:56.9195824', 'ExchangeTransactTime': '2024-05-10T15:09:56+05:30', 'LastUpdateDateTime': '2024-05-10T15:09:56.9496825', 'OrderExpiryDate': '1980-01-01T00:00:00', 'CancelRejectReason': '', 'OrderUniqueIdentifier': 'leg1', 'OrderLegStatus': 'SingleOrderLeg', 'IsSpread': False, 'BoLegDetails': 0, 'BoEntryOrderId': '', 'OrderAverageTradedPriceAPI': 'NaN', 'OrderSideAPI': 'BUY', 'OrderGeneratedDateTimeAPI': '10-05-2024 15:09:56', 'ExchangeTransactTimeAPI': '10-05-2024 15:09:56', 'LastUpdateDateTimeAPI': '10-05-2024 15:09:56', 'OrderExpiryDateAPI': '01-01-1980 00:00:00', 'AlgoID': '', 'AlgoCategory': 0, 'MessageSynchronizeUniqueKey': 'IIFL11', 'MessageCode': 9004, 'MessageVersion': 4, 'TokenID': 0, 'ApplicationType': 146, 'SequenceNumber': 1375082052251163, 'TradingSymbol': 'NIFTY 16MAY2024 PE 22200'}
,{'LoginID': 'IIFL11', 'ClientID': 'IIFL11', 'AppOrderID': 1210046141, 'OrderReferenceID': '', 'GeneratedBy': 'TWSAPI', 'ExchangeOrderID': 'X_137509100', 'OrderCategoryType': 'NORMAL', 'ExchangeSegment': 'NSEFO', 'ExchangeInstrumentID': 51674, 'OrderSide': 'Sell', 'OrderType': 'StopLimit', 'ProductType': 'NRML', 'TimeInForce': 'DAY', 'OrderPrice': 192.1, 'OrderQuantity': 50, 'OrderStopPrice': 194.1, 'OrderStatus': 'New', 'OrderAverageTradedPrice': '', 'LeavesQuantity': 50, 'CumulativeQuantity': 0, 'OrderDisclosedQuantity': 0, 'OrderGeneratedDateTime': '2024-05-10T15:10:00.3282599', 'ExchangeTransactTime': '2024-05-10T15:10:00+05:30', 'LastUpdateDateTime': '2024-05-10T15:10:00.3804849', 'OrderExpiryDate': '1980-01-01T00:00:00', 'CancelRejectReason': '', 'OrderUniqueIdentifier': 'leg1_sl', 'OrderLegStatus': 'SingleOrderLeg', 'IsSpread': False, 'BoLegDetails': 0, 'BoEntryOrderId': '', 'OrderAverageTradedPriceAPI': 'NaN', 'OrderSideAPI': 'SELL', 'OrderGeneratedDateTimeAPI': '10-05-2024 15:10:00', 'ExchangeTransactTimeAPI': '10-05-2024 15:10:00', 'LastUpdateDateTimeAPI': '10-05-2024 15:10:00', 'OrderExpiryDateAPI': '01-01-1980 00:00:00', 'AlgoID': '', 'AlgoCategory': 0, 'MessageSynchronizeUniqueKey': 'IIFL11', 'MessageCode': 9004, 'MessageVersion': 4, 'TokenID': 0, 'ApplicationType': 146, 'SequenceNumber': 1375082052251180, 'TradingSymbol': 'NIFTY 16MAY2024 PE 22200'}
]

# %%
pd.DataFrame(data)
# Out:
#   LoginID ClientID  AppOrderID OrderReferenceID GeneratedBy ExchangeOrderID  \
# 0  IIFL11   IIFL11  1210046140                       TWSAPI     X_137509099
# 1  IIFL11   IIFL11  1210046141                       TWSAPI     X_137509100
#
#   OrderCategoryType ExchangeSegment  ExchangeInstrumentID OrderSide  ...  \
# 0            NORMAL           NSEFO                 51674       Buy  ...
# 1            NORMAL           NSEFO                 51674      Sell  ...
#
#     OrderExpiryDateAPI AlgoID AlgoCategory  MessageSynchronizeUniqueKey  \
# 0  01-01-1980 00:00:00                   0                       IIFL11
# 1  01-01-1980 00:00:00                   0                       IIFL11
#
#    MessageCode  MessageVersion TokenID ApplicationType    SequenceNumber  \
# 0         9004               4       0             146  1375082052251163
# 1         9004               4       0             146  1375082052251180
#
#               TradingSymbol
# 0  NIFTY 16MAY2024 PE 22200
# ...
